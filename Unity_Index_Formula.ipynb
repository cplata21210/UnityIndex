# %%
import pandas as pd
import matplotlib.pyplot as plt
import TopUnity as AgC

# %%
df = pd.read_csv('TopUnity_Data.csv', encoding = 'latin-1', sep=';')
n = 25
TopUni = AgC.TopU(df, False)
AgC.plot_TopUnity(TopUni,n)
plt.axhline(TopUni['LocalCitations'][0:n].mean(), color = 'k', linestyle = '--')
plt.axvline(TopUni['Articles'][0:n].mean(), color = 'k', linestyle = '--')

# %%
TopUni
# Out:
#               Authors Articles LocalCitations h_index TopArt TopCit  TopH  \
# 0              Fey Cf        6             25       5      7     42     7
# 1            Kapoor M        4             56       3     17     14    29
# 2                He Q        4             44       3     17     26    29
# 3               Liu H        5             20       4     11     58    14
# 4            Argote L       10             14       9      1     91     1
# ...               ...      ...            ...     ...    ...    ...   ...
# 3151           Wang D        1              0       0    395   1436  2920
# 3152  Wuryaningrat Nf        1              0       0    395   1436  2920
# 3153            Xie L        1              0       0    395   1436  2920
# 3154            Xie X        1              0       0    395   1436  2920
# 3155          Yepes V        1              0       0    395   1436  2920
#
#       Suma TopUnity  Gain
# 0       56        1     6
# 1       60        2    15
# 2       72        3    14
# 3       83        4     7
# 4       93        5    -4
# ...    ...      ...   ...
# 3151  4751     3039 -2644
# 3152  4751     3039 -2644
# 3153  4751     3039 -2644
# 3154  4751     3039 -2644
# 3155  4751     3039 -2644
#
# [3156 rows x 10 columns]
